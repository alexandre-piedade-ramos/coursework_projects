# %% [markdown]
# # Projeto de Bases de Dados - Parte 2
#
# ### Docente Responsável
#
# Prof. Flávio Martins
# BD26 L05
# ### Grupo 86
# <dl>
#     <dt>10 horas (33.3%)</dt>
#     <dd>ist1102598 Alexandre Ramos</dd>
#     <dt>10 horas (33.3%)</dt>
#     <dd>ist1107249 David Rogério</dd>
#     <dt>10 horas (33.3%)</dt>
#     <dd>ist1106100 Guilherme Sousa</dd>
# <dl>

# %%
# %load_ext sql
# %config SqlMagic.displaycon = 0
# %config SqlMagic.displaylimit = 100
# %sql postgresql+psycopg://postgres:postgres@postgres/postgres
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# Connecting and switching to connection 'postgresql+psycopg://postgres:***@postgres/postgres'
# There's a new jupysql version available (0.10.10), you're running 0.10.9. To upgrade: pip install jupysql --upgrade

# %% [markdown]
# ## 0. Carregamento da Base de Dados
#
# Crie a base de dados “Saude” no PostgreSQL e execute os comandos para criação das tabelas desta base de dados apresentados de seguida

# %%
# %%sql
#
# DROP TABLE IF EXISTS clinica CASCADE;
# DROP TABLE IF EXISTS enfermeiro CASCADE;
# DROP TABLE IF EXISTS medico CASCADE;
# DROP TABLE IF EXISTS trabalha CASCADE;
# DROP TABLE IF EXISTS paciente CASCADE;
# DROP TABLE IF EXISTS receita CASCADE;
# DROP TABLE IF EXISTS consulta CASCADE;
# DROP TABLE IF EXISTS observacao CASCADE;
#
# CREATE TABLE clinica(
# 	nome VARCHAR(80) PRIMARY KEY,
# 	telefone VARCHAR(15) UNIQUE NOT NULL CHECK (telefone ~ '^[0-9]+$'),
# 	morada VARCHAR(255) UNIQUE NOT NULL
# );
#
# CREATE TABLE enfermeiro(
# 	nif CHAR(9) PRIMARY KEY CHECK (nif ~ '^[0-9]+$'),
# 	nome VARCHAR(80) UNIQUE NOT NULL,
# 	telefone VARCHAR(15) NOT NULL CHECK (telefone ~ '^[0-9]+$'),
# 	morada VARCHAR(255) NOT NULL,
# 	nome_clinica VARCHAR(80) NOT NULL REFERENCES clinica (nome)
# );
#
# CREATE TABLE medico(
# 	nif CHAR(9) PRIMARY KEY CHECK (nif ~ '^[0-9]+$'),
# 	nome VARCHAR(80) UNIQUE NOT NULL,
# 	telefone VARCHAR(15) NOT NULL CHECK (telefone ~ '^[0-9]+$'),
# 	morada VARCHAR(255) NOT NULL,
# 	especialidade VARCHAR(80) NOT NULL
# );
#
# CREATE TABLE trabalha(
# nif CHAR(9) NOT NULL REFERENCES medico,
# nome VARCHAR(80) NOT NULL REFERENCES clinica,
# dia_da_semana SMALLINT,
# PRIMARY KEY (nif, dia_da_semana)
# );
#
# CREATE TABLE paciente(
# 	ssn CHAR(11) PRIMARY KEY CHECK (ssn ~ '^[0-9]+$'),
# nif CHAR(9) UNIQUE NOT NULL CHECK (nif ~ '^[0-9]+$'),
# 	nome VARCHAR(80) NOT NULL,
# 	telefone VARCHAR(15) NOT NULL CHECK (telefone ~ '^[0-9]+$'),
# 	morada VARCHAR(255) NOT NULL,
# 	data_nasc DATE NOT NULL
# );
#
# CREATE TABLE consulta(
# 	id SERIAL PRIMARY KEY,
# 	ssn CHAR(11) NOT NULL REFERENCES paciente,
# 	nif CHAR(9) NOT NULL REFERENCES medico,
# 	nome VARCHAR(80) NOT NULL REFERENCES clinica,
# 	data DATE NOT NULL,
# 	hora TIME NOT NULL,
# 	codigo_sns CHAR(12) UNIQUE CHECK (codigo_sns ~ '^[0-9]+$'),
# 	UNIQUE(ssn, data, hora),
# 	UNIQUE(nif, data, hora)
# );
#
# CREATE TABLE receita(
# 	codigo_sns VARCHAR(12) NOT NULL REFERENCES consulta (codigo_sns),
# 	medicamento VARCHAR(155) NOT NULL,
# 	quantidade SMALLINT NOT NULL CHECK (quantidade > 0),
# 	PRIMARY KEY (codigo_sns, medicamento)
# );
#
# CREATE TABLE observacao(
# 	id INTEGER NOT NULL REFERENCES consulta,
# 	parametro VARCHAR(155) NOT NULL,
# 	valor FLOAT,
# PRIMARY KEY (id, parametro)
# );
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# ## 1. Restrições de Integridade
#
# Apresente o código para implementar as seguintes restrições de integridade, se necessário, com recurso a extensões procedimentais SQL (Stored Procedures e Triggers):

# %% [markdown]
# (RI-1) Os horários das consultas são à hora exata ou meia-hora no horário 8-13h e 14-19h

# %%
# %%sql
# -- (RI-1)
# ALTER TABLE consulta
# ADD CONSTRAINT hora_check
# CHECK (
#     (EXTRACT(hour FROM hora) BETWEEN 8 AND 18)
#     AND (EXTRACT(minute FROM hora) = 0 OR EXTRACT(minute FROM hora) = 30)
#     AND EXTRACT(hour FROM hora) != 13
# );
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# (RI-2) Um médico não se pode consultar a si próprio, embora possa ser paciente de outros médicos no sistema

# %%
# %%sql
# -- (RI-2)
# CREATE OR REPLACE FUNCTION medico_check() RETURNS trigger AS $$
#     BEGIN
#         IF new.nif = (SELECT nif from paciente WHERE ssn = new.ssn) THEN
#             RAISE EXCEPTION 'Um médico não se pode consultar a si próprio';
#         END IF;
#         RETURN NEW;
#     END;
# $$ LANGUAGE plpgsql;
# CREATE TRIGGER check_medico BEFORE INSERT ON consulta
#     FOR EACH ROW EXECUTE FUNCTION medico_check();
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# (RI-3) Um médico só pode dar consultas na clínica em que trabalha no dia da semana correspondente à data da consulta

# %%
# %%sql
# -- (RI-3)
# CREATE OR REPLACE FUNCTION medico_escala_check() RETURNS trigger AS $$
#     BEGIN
#         IF new.nif NOT IN (SELECT nif from medico)
#             THEN RAISE EXCEPTION 'NIF não corresponde a nenhum medico';
#         END IF;
#         IF new.nome NOT IN (SELECT nome from clinica)
#             THEN RAISE EXCEPTION 'Não temos uma clinica com esse nome';
#         END IF;
#         IF EXTRACT(isodow FROM new.data) NOT IN (SELECT dia_da_semana from trabalha WHERE nif = new.nif and nome =new.nome)
#             THEN RAISE EXCEPTION 'O medico não trabalha nessa clinica nesse dia da semana';
#         END IF;
#         RETURN NEW;
#     END;
# $$ LANGUAGE plpgsql;
# CREATE TRIGGER check_escala_medico BEFORE INSERT ON consulta
#     FOR EACH ROW EXECUTE FUNCTION medico_escala_check();
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# ## 2. Preenchimento da Base de Dados
#
# Preencha todas as tabelas da base de dados de forma consistente (após execução do ponto anterior) com os seguintes requisitos adicionais de cobertura:
# - 5 clínicas, de pelo menos 3 localidades diferentes do distrito de Lisboa
# - 5-6 enfermeiros por clínica
# - 20 médicos de especialidade ‘clínica geral’ e 40 outros distribuídos como entender por até 5 outras especialidades médicas (incluindo pelo menos, ‘ortopedia’ e ‘cardiologia’). Cada médico deve trabalhar em pelo menos duas clínicas, e em cada clínica a cada dia da semana (incluindo fins de semana), devem estar pelo menos 8 médicos
# - Cerca de 5.000 pacientes
# - Um número mínimo de consultas em 2023 e 2024 tais que cada paciente tem pelo menos uma consulta, e em cada dia há pelo menos 20 consultas por clínica, e pelo menos 2 consultas por médico
# - ~80% das consultas tem receita médica associada, e as receitas têm 1 a 6 medicamentos em quantidades entre 1 e 3
# - Todas as consultas têm 1 a 5 observações de sintomas (com parâmetro mas sem valor) e 0 a 3 observações métricas (com parâmetro e valor). Deve haver ~50 parâmetros diferentes para os sintomas (sem valor) e ~20 parâmetros diferentes para as observações métricas (com valor) e os dois conjuntos devem ser disjuntos.
# - Todas as moradas são nacionais e seguem o formato Português, terminando com código postal: XXXX-XXX e de seguida a localidade.
# Deve ainda garantir que todas as consultas necessárias para a realização dos pontos seguintes do projeto produzem um resultado não vazio.
#
# O código para preenchimento da base de dados deve ser compilado num ficheiro "populate.sql", anexado ao relatório, que contém com comandos INSERT ou alternativamente comandos COPY que populam as tabelas a partir de ficheiros de texto, também eles anexados ao relatório.

# %%
# !psql -U postgres -d postgres -f ./populate.sql
# Out:
# BEGIN
# COPY 5
# COPY 30
# COPY 60
# COPY 300
# COPY 5000
# COPY 93984
# COPY 299479
# COPY 186183
#  setval
# --------
#   93984
# (1 row)
#
# INSERT 0 1
# INSERT 0 13
# INSERT 0 13
# INSERT 0 13
# COMMIT
# ANALYZE

# %% [markdown]
# ## 3. Desenvolvimento de Aplicação
#
# Crie um protótipo de RESTful web service para gestão de consultas por acesso programático à base de dados ‘Saude’ através de uma API que devolve respostas em JSON, implementando os seguintes endpoints REST:
#
# |Endpoint|Descrição|
# |--------|---------|
# |/|Lista todas as clínicas (nome e morada).|
# |/c/\<clinica>/|Lista todas as especialidades oferecidas na \<clinica>.|
# |/c/\<clinica>/\<especialidade>/|Lista todos os médicos (nome) da \<especialidade> que trabalham na <clínica> e os primeiros três horários disponíveis para consulta de cada um deles (data e hora).|
# |/a/\<clinica>/registar/|Registra uma marcação de consulta na \<clinica> na base de dados (populando a respectiva tabela). Recebe como argumentos um paciente, um médico, e uma data e hora (posteriores ao momento de agendamento).|
# |/a/\<clinica>/cancelar/|Cancela uma marcação de consulta que ainda não se realizou na \<clinica> (o seu horário é posterior ao momento do cancelamento), removendo a entrada da respectiva tabela na base de dados. Recebe como argumentos um paciente, um médico, e uma data e hora.|

# %% [markdown]
# ### Explicação da arquitetura da aplicação web, indicando a correspondência entre as funções app.py e os endpoints pedidos
#
# ### Explicação da arquitetura da aplicação web, incluindo a descrição dos vários ficheiros na pasta web/arquivos e a relação entre eles
#
# O único ficheiro na pasta web é `app.py`.
# A aplicação é lançada correndo `flask --app app.py run` a partir da pasta onde está o `app.py`.
#
# Fica uma breve descrição de cada endpoint:
#
# ### /
# - **Função**: list_clinics()
# - **Metodos**: GET
# - **Response Codes**: 200, 500
# - **Formato do Conteudo**: json
# - **Exemplo de Uso**: `curl --silent -w "%{http_code}\n" -X GET "localhost:5000/" | jq`
#
# ### /c/\<clinica>
# - **Função**: list_especialidades()
# - **Metodos**: GET
# - **Response Codes**: 200, 400, 500
# - **Formato do Conteudo**: json
# - **Exemplo de Uso**: `curl --silent -w "%{http_code}\n" -X GET "localhost:5000/c/Blue/" | jq`
#
# ### /c/\<clinica>/\<especialidade>
# - **Função**: available_time_slots(clinica, especialidade)
# - **Metodos**: GET
# - **Response Codes****: 200, 400, 500
# - **Formato do Conteudo**: json
# - **Exemplo de Uso**: `curl --silent -w "%{http_code}\n" -X GET "localhost:5000/c/Blue/Ortopedia/" | jq`
#
# ### /a/\<clinica>/\<registar>/
# - **Função**: marcar_consulta(clinica)
# - **Metodos**: POST
# - **Response Codes**: 200, 400, 500
# - **Formato do Conteudo**: json
# - **Exemplo de Uso**: `curl --silent -w "%{http_code}\n" -X POST "localhost:5000/a/Blue/registar/?medico=235777723&data=2024-06-06&hora=08:30:00&paciente=80297386184" | jq`
#
# ### /a/\<clinica>/\<cancelar>/
# - **Função**: cancelar_consulta(clinica)
# - **Metodos**: DELETE
# - **Response Codes**: 200, 400, 500
# - **Formato do Conteudo**: json
# - **Exemplo de Uso**: `curl --silent -w "%{http_code}\n" -X DELETE "localhost:5000/a/Blue/cancelar/?medico=235777723&data=2024-06-06&hora=08:30:00&paciente=80297386184" | jq`

# %% [markdown]
# ## 4. Vistas
#
# Crie uma vista materializada que detalhe as informações mais importantes sobre as consultas dos pacientes, combinando a informação de várias tabelas da base de dados. A vista deve ter o seguinte esquema:
#
# ### *historial_paciente(id, ssn, nif, nome, data, ano, mes, dia_do_mes, localidade, especialidade, tipo, chave, valor)*
#
# em que:
# - *id, ssn, nif, nome* e *data*: correspondem ao atributos homónimos da tabela **consulta**
# - *ano*, *mes* e *dia_do_mes*: são derivados do atributo *data* da tabela **consulta**
# - *localidade*: é derivado do atributo *morada* da tabela **clinica**
# - *especialidade*: corresponde ao atributo homónimo da tabela **medico**
# - *tipo*: toma os valores ‘observacao’ ou ‘receita’ consoante o preenchimento dos campos seguintes
# - *chave*: corresponde ao atributo *parametro* da tabela **observacao** ou ao atributo *medicamento* da tabela **receita**
# - *valor*: corresponde ao atributo *valor* da tabela **observacao** ou ao atributo *quantidade* da tabela **receita**

# %%
# %%sql
# create materialized view historial_paciente as
# (
#
#     with part1 as(
#         select
#             id, ssn, nif, con.nome, data, codigo_sns,
#             extract(year from con.data ) as ano,
#             extract(month from con.data ) as mes,
#             extract(day from con.data) as dia_do_mes,
#             reverse(substring(reverse(cli.morada) from '(.*)\s-')) as localidade,
#             med.especialidade
#         from
#             consulta con
#             join clinica cli using (nome)
#             join medico med using (nif)
#     )
#     (
#     select
#         id, ssn, nif, nome, data,
#         ano, mes, dia_do_mes, localidade, especialidade,
#         'observacao' as tipo,
#         obs.parametro as chave,
#         obs.valor as valor
#     from part1 join observacao obs using (id)
#     )
#     UNION
#     (
#     select
#         id, ssn, nif, nome, data,
#         ano, mes, dia_do_mes, localidade, especialidade,
#         'receita' as tipo,
#         rec.medicamento as chave,
#         rec.quantidade as valor
#     from part1 join receita rec using (codigo_sns)
#     )
# );
# Out:
# 485688 rows affected.
# ++
# ||
# ++
# ++

# %% [markdown]
# ## 5. Análise de Dados (SQL e OLAP
#
# Usando a vista desenvolvida no ponto anterior, complementada com outras tabelas da base de dados ‘Saude’ quando necessário, apresente a consulta SQL mais sucinta para cada um dos seguintes objetivos analíticos. Pode usar as instruções ROLLUP, CUBE, GROUPING SETS ou as cláusulas UNION of GROUP BY para os objetivos em que lhe parecer adequado.

# %% [markdown]
# 1. Determinar que paciente(s) tiveram menos progresso no tratamento das suas doenças do foro ortopédico para atribuição de uma consulta gratuita. Considera-se que o indicador de falta de progresso é o intervalo temporal máximo entre duas observações do mesmo sintoma (i.e. registos de tipo ‘observacao’ com a mesma chave e com valor NULL) em consultas de ortopedia.

# %%
# %%sql
# with idk as(
#     select ssn, chave, max(data) - min(data) as delta
#     from historial_paciente
#     where tipo='observacao' and valor is null and especialidade='Ortopedia'
#     group by ssn,chave
# )
# select ssn, delta
# from idk
# where delta >= (select max(delta) from idk);
# Out:
# 2 rows affected.
# +-------------+-------+
# |     ssn     | delta |
# +-------------+-------+
# | 12050229766 |  467  |
# | 12050229766 |  467  |
# +-------------+-------+

# %% [markdown]
# 2. Determinar que medicamentos estão a ser usados para tratar doenças crónicas do foro cardiológico. Considera-se que qualificam quaisquer medicamentos receitados ao mesmo paciente (qualquer que ele seja) pelo menos uma vez por mês durante os últimos doze meses, em consultas de cardiologia.

# %%
# %%sql
# select distinct(chave)
# from historial_paciente
# where especialidade='Cardiologia' and tipo='receita'
# and data >= date_trunc('month', current_date) - interval '1 year'
# and data < date_trunc('month', current_date) --floor of month
# group by ssn, chave
# having ( count(distinct(ano,mes))>=12);
# Out:
# 1 rows affected.
# +----------+
# |  chave   |
# +----------+
# | Edoxaban |
# +----------+

# %% [markdown]
# 3. Explorar as quantidades totais receitadas de cada medicamento em 2023, globalmente, e com drill down nas dimensões espaço (localidade > clinica), tempo (mes > dia_do_mes), e médico  (especialidade > nome \[do médico]), separadamente.

# %%
# %%sql
# with grouped_data as(
#     select
#         chave as medicamento,
#         localidade, nome,
#         mes, dia_do_mes,
#         especialidade, nif,
#         count(*) as total
#     from
#         historial_paciente
#     where
#         tipo='receita' and ano='2023'
#     group by distinct
#         chave,
#         grouping sets
#         (
#             rollup(localidade, nome),
#             rollup(mes,dia_do_mes),
#             rollup(especialidade, nif)
#             --Resultados podiam ser errados
#             --se 2 medicos tiverem o mesmo nome
#         )
# )
# select
#     medicamento,
#     localidade, gp.nome as nome_clinica,
#     mes, dia_do_mes,
#     gp.especialidade, med.nome as nome_medico,
#     total
# from
#     grouped_data gp
#     left join medico med using (nif)
# order by medicamento, localidade, gp.nome, mes , dia_do_mes, gp.especialidade, med.nome
# ;
# Out:
# 79193 rows affected.
# +------------------+---------------------------+---------------+------+------------+---------------+-------------+-------+
# |   medicamento    |         localidade        |  nome_clinica | mes  | dia_do_mes | especialidade | nome_medico | total |
# +------------------+---------------------------+---------------+------+------------+---------------+-------------+-------+
# | Abilify Maintena | ALDEIA GALEGA DA MERCEANA |   Multicare   | None |    None    |      None     |     None    |  136  |
# | Abilify Maintena | ALDEIA GALEGA DA MERCEANA |      None     | None |    None    |      None     |     None    |  136  |
# | Abilify Maintena |          AMADORA          | Interclínicas | None |    None    |      None     |     None    |  144  |
# | Abilify Maintena |          AMADORA          | Santa Clínica | None |    None    |      None     |     None    |  151  |
# | Abilify Maintena |          AMADORA          |  Ultramedical | None |    None    |      None     |     None    |  138  |
# | Abilify Maintena |          AMADORA          |      None     | None |    None    |      None     |     None    |  433  |
# | Abilify Maintena |     ARRUDA DOS VINHOS     |      Blue     | None |    None    |      None     |     None    |  134  |
# | Abilify Maintena |     ARRUDA DOS VINHOS     |      None     | None |    None    |      None     |     None    |  134  |
# | Abilify Maintena |            None           |      None     |  1   |     1      |      None     |     None    |   3   |
# | Abilify Maintena |            None           |      None     |  1   |     2      |      None     |     None    |   3   |
# | Abilify Maintena |            None           |      None     |  1   |     4      |      None     |     None    |   2   |
# | Abilify Maintena |            None           |      None     |  1   |     6      |      None     |     None    |   1   |
# | Abilify Maintena |            None           |      None     |  1   |     7      |      None     |     None    |   4   |
# | Abilify Maintena |            None           |      None     |  1   |     9      |      None     |     None    |   3   |
# | Abilify Maintena |            None           |      None     |  1   |     10     |      None     |     None    |   5   |
# | Abilify Maintena |            None           |      None     |  1   |     11     |      None     |     None    |   3   |
# | Abilify Maintena |            None           |      None     |  1   |     12     |      None     |     None    |   2   |
# | Abilify Maintena |            None           |      None     |  1   |     13     |      None     |     None    |   3   |
# | Abilify Maintena |            None           |      None     |  1   |     14     |      None     |     None    |   3   |
# | Abilify Maintena |            None           |      None     |  1   |     15     |      None     |     None    |   3   |
# | Abilify Maintena |            None           |      None     |  1   |     16     |      None     |     None    |   2   |
# | Abilify Maintena |            None           |      None     |  1   |     17     |      None     |     None    |   3   |
# | Abilify Maintena |            None           |      None     |  1   |     18     |      None     |     None    |   7   |
# | Abilify Maintena |            None           |      None     |  1   |     20     |      None     |     None    |   3   |
# | Abilify Maintena |            None           |      None     |  1   |     22     |      None     |     None    |   2   |
# | Abilify Maintena |            None           |      None     |  1   |     23     |      None     |     None    |   2   |
# | Abilify Maintena |            None           |      None     |  1   |     24     |      None     |     None    |   2   |
# | Abilify Maintena |            None           |      None     |  1   |     25     |      None     |     None    |   1   |
# | Abilify Maintena |            None           |      None     |  1   |     26     |      None     |     None    |   2   |
# | Abilify Maintena |            None           |      None     |  1   |     28     |      None     |     None    |   4   |
# | Abilify Maintena |            None           |      None     |  1   |     29     |      None     |     None    |   3   |
# | Abilify Maintena |            None           |      None     |  1   |     30     |      None     |     None    |   1   |
# | Abilify Maintena |            None           |      None     |  1   |     31     |      None     |     None    |   1   |
# | Abilify Maintena |            None           |      None     |  1   |    None    |      None     |     None    |   68  |
# | Abilify Maintena |            None           |      None     |  2   |     1      |      None     |     None    |   2   |
# | Abilify Maintena |            None           |      None     |  2   |     2      |      None     |     None    |   3   |
# | Abilify Maintena |            None           |      None     |  2   |     4      |      None     |     None    |   5   |
# | Abilify Maintena |            None           |      None     |  2   |     5      |      None     |     None    |   2   |
# | Abilify Maintena |            None           |      None     |  2   |     6      |      None     |     None    |   2   |
# | Abilify Maintena |            None           |      None     |  2   |     8      |      None     |     None    |   3   |
# | Abilify Maintena |            None           |      None     |  2   |     9      |      None     |     None    |   2   |
# | Abilify Maintena |            None           |      None     |  2   |     11     |      None     |     None    |   3   |
# | Abilify Maintena |            None           |      None     |  2   |     12     |      None     |     None    |   1   |
# | Abilify Maintena |            None           |      None     |  2   |     13     |      None     |     None    |   4   |
# | Abilify Maintena |            None           |      None     |  2   |     14     |      None     |     None    |   5   |
# | Abilify Maintena |            None           |      None     |  2   |     15     |      None     |     None    |   1   |
# | Abilify Maintena |            None           |      None     |  2   |     16     |      None     |     None    |   5   |
# | Abilify Maintena |            None           |      None     |  2   |     19     |      None     |     None    |   1   |
# | Abilify Maintena |            None           |      None     |  2   |     20     |      None     |     None    |   1   |
# | Abilify Maintena |            None           |      None     |  2   |     21     |      None     |     None    |   2   |
# | Abilify Maintena |            None           |      None     |  2   |     23     |      None     |     None    |   1   |
# | Abilify Maintena |            None           |      None     |  2   |     24     |      None     |     None    |   2   |
# | Abilify Maintena |            None           |      None     |  2   |     25     |      None     |     None    |   3   |
# | Abilify Maintena |            None           |      None     |  2   |     26     |      None     |     None    |   2   |
# | Abilify Maintena |            None           |      None     |  2   |     27     |      None     |     None    |   1   |
# | Abilify Maintena |            None           |      None     |  2   |     28     |      None     |     None    |   3   |
# | Abilify Maintena |            None           |      None     |  2   |    None    |      None     |     None    |   54  |
# | Abilify Maintena |            None           |      None     |  3   |     1      |      None     |     None    |   2   |
# | Abilify Maintena |            None           |      None     |  3   |     2      |      None     |     None    |   5   |
# | Abilify Maintena |            None           |      None     |  3   |     3      |      None     |     None    |   1   |
# | Abilify Maintena |            None           |      None     |  3   |     4      |      None     |     None    |   2   |
# | Abilify Maintena |            None           |      None     |  3   |     6      |      None     |     None    |   2   |
# | Abilify Maintena |            None           |      None     |  3   |     7      |      None     |     None    |   3   |
# | Abilify Maintena |            None           |      None     |  3   |     8      |      None     |     None    |   2   |
# | Abilify Maintena |            None           |      None     |  3   |     9      |      None     |     None    |   4   |
# | Abilify Maintena |            None           |      None     |  3   |     10     |      None     |     None    |   3   |
# | Abilify Maintena |            None           |      None     |  3   |     11     |      None     |     None    |   1   |
# | Abilify Maintena |            None           |      None     |  3   |     12     |      None     |     None    |   3   |
# | Abilify Maintena |            None           |      None     |  3   |     14     |      None     |     None    |   2   |
# | Abilify Maintena |            None           |      None     |  3   |     15     |      None     |     None    |   2   |
# | Abilify Maintena |            None           |      None     |  3   |     16     |      None     |     None    |   2   |
# | Abilify Maintena |            None           |      None     |  3   |     18     |      None     |     None    |   1   |
# | Abilify Maintena |            None           |      None     |  3   |     19     |      None     |     None    |   1   |
# | Abilify Maintena |            None           |      None     |  3   |     20     |      None     |     None    |   2   |
# | Abilify Maintena |            None           |      None     |  3   |     21     |      None     |     None    |   2   |
# | Abilify Maintena |            None           |      None     |  3   |     22     |      None     |     None    |   3   |
# | Abilify Maintena |            None           |      None     |  3   |     23     |      None     |     None    |   3   |
# | Abilify Maintena |            None           |      None     |  3   |     25     |      None     |     None    |   2   |
# | Abilify Maintena |            None           |      None     |  3   |     26     |      None     |     None    |   4   |
# | Abilify Maintena |            None           |      None     |  3   |     27     |      None     |     None    |   2   |
# | Abilify Maintena |            None           |      None     |  3   |     28     |      None     |     None    |   3   |
# | Abilify Maintena |            None           |      None     |  3   |     29     |      None     |     None    |   1   |
# | Abilify Maintena |            None           |      None     |  3   |    None    |      None     |     None    |   58  |
# | Abilify Maintena |            None           |      None     |  4   |     1      |      None     |     None    |   2   |
# | Abilify Maintena |            None           |      None     |  4   |     2      |      None     |     None    |   2   |
# | Abilify Maintena |            None           |      None     |  4   |     3      |      None     |     None    |   5   |
# | Abilify Maintena |            None           |      None     |  4   |     4      |      None     |     None    |   1   |
# | Abilify Maintena |            None           |      None     |  4   |     5      |      None     |     None    |   2   |
# | Abilify Maintena |            None           |      None     |  4   |     7      |      None     |     None    |   1   |
# | Abilify Maintena |            None           |      None     |  4   |     9      |      None     |     None    |   2   |
# | Abilify Maintena |            None           |      None     |  4   |     10     |      None     |     None    |   4   |
# | Abilify Maintena |            None           |      None     |  4   |     11     |      None     |     None    |   4   |
# | Abilify Maintena |            None           |      None     |  4   |     12     |      None     |     None    |   2   |
# | Abilify Maintena |            None           |      None     |  4   |     13     |      None     |     None    |   3   |
# | Abilify Maintena |            None           |      None     |  4   |     14     |      None     |     None    |   3   |
# | Abilify Maintena |            None           |      None     |  4   |     15     |      None     |     None    |   2   |
# | Abilify Maintena |            None           |      None     |  4   |     16     |      None     |     None    |   1   |
# | Abilify Maintena |            None           |      None     |  4   |     17     |      None     |     None    |   4   |
# | Abilify Maintena |            None           |      None     |  4   |     18     |      None     |     None    |   2   |
# | Abilify Maintena |            None           |      None     |  4   |     19     |      None     |     None    |   1   |
# +------------------+---------------------------+---------------+------+------------+---------------+-------------+-------+
# Truncated to displaylimit of 100.

# %% [markdown]
# 4. Determinar se há enviesamento na medição de algum parâmetros entre clínicas, especialidades médicas ou médicos, sendo para isso necessário listar o valor médio e desvio padrão de todos os parâmetros de observações métricas (i.e. com valor não NULL) com drill down na dimensão médico (globalmente > especialidade > nome \[do médico]) e drill down adicional (sobre o anterior) por clínica.

# %%
# %%sql
# with grouped_data as
# (
#     select
#         chave as parametro,
#         especialidade,
#         nif,
#         nome as nome_clinica,
#         avg(valor) as avg,
#         stddev(valor) as stddev
#     from
#         historial_paciente
#     where
#         tipo='observacao' and valor is not null
#     group by
#         chave,
#         grouping sets
#         (
#             nome, --across clinics
#             rollup(especialidade, nif, nome)
#             /*chave, esp, nif, nome permite comparar
#             as medições de um medico nas diferentes
#             clinicas em que trabalha*/
#         )
# )
# select
#     parametro,
#     gp.especialidade,
#     med.nome as nome_medico,
#     nome_clinica,
#     avg,
#     stddev
# from
#     grouped_data gp
#     left join medico med using (nif)
# order by
#     parametro, especialidade, nome_medico, nome_clinica
# ;
# Out:
# 8316 rows affected.
# +--------------------+----------------------------------------------+--------------------+---------------+--------------------+--------------------+
# |     parametro      |                especialidade                 |    nome_medico     |  nome_clinica |        avg         |       stddev       |
# +--------------------+----------------------------------------------+--------------------+---------------+--------------------+--------------------+
# | ALT_unidades_por_L |             Anatomia Patológica              | Agostinho Sequeira |      Blue     | 36.50411764705882  | 1.1246891727469062 |
# | ALT_unidades_por_L |             Anatomia Patológica              | Agostinho Sequeira | Interclínicas |       36.06        | 1.4732277488562309 |
# | ALT_unidades_por_L |             Anatomia Patológica              | Agostinho Sequeira |   Multicare   | 35.922222222222224 | 0.9671191469743731 |
# | ALT_unidades_por_L |             Anatomia Patológica              | Agostinho Sequeira | Santa Clínica | 36.32444444444444  | 1.0460751419541434 |
# | ALT_unidades_por_L |             Anatomia Patológica              | Agostinho Sequeira |  Ultramedical | 36.07083333333333  | 1.2803654189568694 |
# | ALT_unidades_por_L |             Anatomia Patológica              | Agostinho Sequeira |      None     | 36.224705882352936 |  1.16651345622199  |
# | ALT_unidades_por_L |             Anatomia Patológica              |        None        |      None     | 36.224705882352936 |  1.16651345622199  |
# | ALT_unidades_por_L |        Angiologia e Cirurgia Vascular        |  Laura Magalhães   |      Blue     | 36.278499999999994 | 1.1021523201636434 |
# | ALT_unidades_por_L |        Angiologia e Cirurgia Vascular        |  Laura Magalhães   | Interclínicas | 36.17851851851852  | 1.2571387038818418 |
# | ALT_unidades_por_L |        Angiologia e Cirurgia Vascular        |  Laura Magalhães   |   Multicare   | 36.43368421052631  | 1.2005610286968877 |
# | ALT_unidades_por_L |        Angiologia e Cirurgia Vascular        |  Laura Magalhães   | Santa Clínica |     36.383125      | 1.2353068107424425 |
# | ALT_unidades_por_L |        Angiologia e Cirurgia Vascular        |  Laura Magalhães   |  Ultramedical | 36.474999999999994 | 1.3590084054757876 |
# | ALT_unidades_por_L |        Angiologia e Cirurgia Vascular        |  Laura Magalhães   |      None     | 36.32718750000001  | 1.2062544927650176 |
# | ALT_unidades_por_L |        Angiologia e Cirurgia Vascular        |        None        |      None     | 36.32718750000001  | 1.2062544927650176 |
# | ALT_unidades_por_L |                 Cardiologia                  | Estanislau Menezes |      Blue     | 36.873333333333335 | 1.4476333873748646 |
# | ALT_unidades_por_L |                 Cardiologia                  | Estanislau Menezes | Interclínicas | 35.915769230769236 | 1.1231960579593327 |
# | ALT_unidades_por_L |                 Cardiologia                  | Estanislau Menezes |   Multicare   | 36.61750000000001  | 1.055591461377618  |
# | ALT_unidades_por_L |                 Cardiologia                  | Estanislau Menezes | Santa Clínica | 36.591249999999995 | 1.113354540716178  |
# | ALT_unidades_por_L |                 Cardiologia                  | Estanislau Menezes |  Ultramedical | 36.17894736842105  | 1.1768408498879162 |
# | ALT_unidades_por_L |                 Cardiologia                  | Estanislau Menezes |      None     | 36.348651685393236 | 1.1949174477108087 |
# | ALT_unidades_por_L |                 Cardiologia                  |   Lídia Pimenta    |      Blue     | 36.67727272727272  | 0.9682295173503027 |
# | ALT_unidades_por_L |                 Cardiologia                  |   Lídia Pimenta    | Interclínicas | 36.54666666666666  | 1.4027535945627887 |
# | ALT_unidades_por_L |                 Cardiologia                  |   Lídia Pimenta    |   Multicare   | 36.34277777777777  | 1.153290971680382  |
# | ALT_unidades_por_L |                 Cardiologia                  |   Lídia Pimenta    | Santa Clínica | 36.824444444444445 | 1.0806382766528848 |
# | ALT_unidades_por_L |                 Cardiologia                  |   Lídia Pimenta    |  Ultramedical |       36.382       | 1.7969591598648602 |
# | ALT_unidades_por_L |                 Cardiologia                  |   Lídia Pimenta    |      None     | 36.57639534883722  | 1.224124092893216  |
# | ALT_unidades_por_L |                 Cardiologia                  |   Tadeu Carneiro   |      Blue     |     35.821875      | 0.9378572652594847 |
# | ALT_unidades_por_L |                 Cardiologia                  |   Tadeu Carneiro   | Interclínicas | 36.847058823529416 | 1.6891187225365543 |
# | ALT_unidades_por_L |                 Cardiologia                  |   Tadeu Carneiro   |   Multicare   | 36.79222222222222  | 1.484161698640824  |
# | ALT_unidades_por_L |                 Cardiologia                  |   Tadeu Carneiro   | Santa Clínica | 36.260000000000005 | 1.438981121025103  |
# | ALT_unidades_por_L |                 Cardiologia                  |   Tadeu Carneiro   |  Ultramedical | 36.19250000000001  | 1.140640978619156  |
# | ALT_unidades_por_L |                 Cardiologia                  |   Tadeu Carneiro   |      None     | 36.39333333333335  | 1.3818307511774364 |
# | ALT_unidades_por_L |                 Cardiologia                  |        None        |      None     | 36.43876447876449  | 1.2667935543848596 |
# | ALT_unidades_por_L |           Cirurgia Cardio-Torácica           | Felícia Hernandes  |      Blue     | 36.79181818181818  | 1.5090117175278541 |
# | ALT_unidades_por_L |           Cirurgia Cardio-Torácica           | Felícia Hernandes  | Interclínicas | 36.50874999999999  | 1.188841873421358  |
# | ALT_unidades_por_L |           Cirurgia Cardio-Torácica           | Felícia Hernandes  |   Multicare   | 36.65565217391305  | 1.1488722774448947 |
# | ALT_unidades_por_L |           Cirurgia Cardio-Torácica           | Felícia Hernandes  | Santa Clínica | 37.10823529411764  | 1.0993704749430349 |
# | ALT_unidades_por_L |           Cirurgia Cardio-Torácica           | Felícia Hernandes  |  Ultramedical | 36.282500000000006 |  1.11701001053543  |
# | ALT_unidades_por_L |           Cirurgia Cardio-Torácica           | Felícia Hernandes  |      None     | 36.68556962025318  | 1.1967024637551078 |
# | ALT_unidades_por_L |           Cirurgia Cardio-Torácica           |   Luzia Carvalho   |      Blue     | 36.426923076923075 | 1.0221169585341392 |
# | ALT_unidades_por_L |           Cirurgia Cardio-Torácica           |   Luzia Carvalho   | Interclínicas | 36.25071428571428  | 1.0678192319339066 |
# | ALT_unidades_por_L |           Cirurgia Cardio-Torácica           |   Luzia Carvalho   |   Multicare   | 36.258750000000006 | 1.1378041717858725 |
# | ALT_unidades_por_L |           Cirurgia Cardio-Torácica           |   Luzia Carvalho   | Santa Clínica |       36.65        | 1.078430231728453  |
# | ALT_unidades_por_L |           Cirurgia Cardio-Torácica           |   Luzia Carvalho   |  Ultramedical | 36.637058823529415 | 1.5919397158257986 |
# | ALT_unidades_por_L |           Cirurgia Cardio-Torácica           |   Luzia Carvalho   |      None     | 36.45807692307694  | 1.192815133228088  |
# | ALT_unidades_por_L |           Cirurgia Cardio-Torácica           |  Miquelina Homem   |      Blue     | 35.682222222222215 | 1.2705096501962647 |
# | ALT_unidades_por_L |           Cirurgia Cardio-Torácica           |  Miquelina Homem   | Interclínicas |       36.379       | 0.8552678866266038 |
# | ALT_unidades_por_L |           Cirurgia Cardio-Torácica           |  Miquelina Homem   |   Multicare   |       36.472       | 1.3593601435969787 |
# | ALT_unidades_por_L |           Cirurgia Cardio-Torácica           |  Miquelina Homem   | Santa Clínica | 36.47538461538462  | 1.364854176488069  |
# | ALT_unidades_por_L |           Cirurgia Cardio-Torácica           |  Miquelina Homem   |  Ultramedical | 35.95714285714286  | 1.040232433874045  |
# | ALT_unidades_por_L |           Cirurgia Cardio-Torácica           |  Miquelina Homem   |      None     | 36.181500000000014 | 1.1906333810628966 |
# | ALT_unidades_por_L |           Cirurgia Cardio-Torácica           |  Raimundo Pacheco  |      Blue     | 36.62809523809525  | 1.014512784777103  |
# | ALT_unidades_por_L |           Cirurgia Cardio-Torácica           |  Raimundo Pacheco  | Interclínicas | 35.82238095238095  | 1.5474815176986905 |
# | ALT_unidades_por_L |           Cirurgia Cardio-Torácica           |  Raimundo Pacheco  |   Multicare   | 36.83411764705882  | 1.1442304118026743 |
# | ALT_unidades_por_L |           Cirurgia Cardio-Torácica           |  Raimundo Pacheco  | Santa Clínica | 36.687272727272735 | 1.3997250812321307 |
# | ALT_unidades_por_L |           Cirurgia Cardio-Torácica           |  Raimundo Pacheco  |  Ultramedical | 35.968095238095245 | 1.2353364685283894 |
# | ALT_unidades_por_L |           Cirurgia Cardio-Torácica           |  Raimundo Pacheco  |      None     | 36.373431372549014 | 1.3277528810232053 |
# | ALT_unidades_por_L |           Cirurgia Cardio-Torácica           |        None        |      None     |  36.4203539823009  | 1.242448143432437  |
# | ALT_unidades_por_L |            Cirurgia Maxilo-facial            |     Eva Mateus     |      Blue     | 35.989374999999995 | 1.3008482809305615 |
# | ALT_unidades_por_L |            Cirurgia Maxilo-facial            |     Eva Mateus     | Interclínicas |       36.408       | 1.4973893070414594 |
# | ALT_unidades_por_L |            Cirurgia Maxilo-facial            |     Eva Mateus     |   Multicare   |       36.568       | 1.447079818116471  |
# | ALT_unidades_por_L |            Cirurgia Maxilo-facial            |     Eva Mateus     | Santa Clínica | 36.11266666666667  | 0.8752180680645634 |
# | ALT_unidades_por_L |            Cirurgia Maxilo-facial            |     Eva Mateus     |  Ultramedical | 36.789444444444456 | 1.2061922206690825 |
# | ALT_unidades_por_L |            Cirurgia Maxilo-facial            |     Eva Mateus     |      None     | 36.374303797468365 | 1.2869449847228678 |
# | ALT_unidades_por_L |            Cirurgia Maxilo-facial            |        None        |      None     | 36.374303797468365 | 1.2869449847228678 |
# | ALT_unidades_por_L |             Cirurgia Pediátrica              |    Antão Távora    |      Blue     | 36.560500000000005 | 1.2889141696956037 |
# | ALT_unidades_por_L |             Cirurgia Pediátrica              |    Antão Távora    | Interclínicas |       36.436       | 1.170737659198962  |
# | ALT_unidades_por_L |             Cirurgia Pediátrica              |    Antão Távora    |   Multicare   | 35.962666666666664 | 1.3428033930479006 |
# | ALT_unidades_por_L |             Cirurgia Pediátrica              |    Antão Távora    | Santa Clínica | 36.199999999999996 | 1.0531856436545266 |
# | ALT_unidades_por_L |             Cirurgia Pediátrica              |    Antão Távora    |  Ultramedical | 36.258666666666656 | 1.5324577210046195 |
# | ALT_unidades_por_L |             Cirurgia Pediátrica              |    Antão Távora    |      None     | 36.29438356164385  | 1.2841707076524886 |
# | ALT_unidades_por_L |             Cirurgia Pediátrica              |        None        |      None     | 36.29438356164385  | 1.2841707076524886 |
# | ALT_unidades_por_L | Cirurgia Plástica e Reconstrutiva e Estética | Maximiliana Abreu  |      Blue     |  36.9223076923077  | 1.4709926005147798 |
# | ALT_unidades_por_L | Cirurgia Plástica e Reconstrutiva e Estética | Maximiliana Abreu  | Interclínicas | 35.97090909090909  | 1.2678048315529848 |
# | ALT_unidades_por_L | Cirurgia Plástica e Reconstrutiva e Estética | Maximiliana Abreu  |   Multicare   | 36.76708333333333  | 1.3636921722220556 |
# | ALT_unidades_por_L | Cirurgia Plástica e Reconstrutiva e Estética | Maximiliana Abreu  | Santa Clínica | 36.85631578947369  | 1.4427258557109306 |
# | ALT_unidades_por_L | Cirurgia Plástica e Reconstrutiva e Estética | Maximiliana Abreu  |  Ultramedical |       36.075       |  1.05088790297319  |
# | ALT_unidades_por_L | Cirurgia Plástica e Reconstrutiva e Estética | Maximiliana Abreu  |      None     | 36.58518518518518  | 1.360593722526228  |
# | ALT_unidades_por_L | Cirurgia Plástica e Reconstrutiva e Estética |        None        |      None     | 36.58518518518518  | 1.360593722526228  |
# | ALT_unidades_por_L |                Clínica geral                 |     Ana Borges     |      Blue     | 36.49111111111111  | 1.2176877262635164 |
# | ALT_unidades_por_L |                Clínica geral                 |     Ana Borges     | Interclínicas | 36.49388888888889  | 1.189325755053671  |
# | ALT_unidades_por_L |                Clínica geral                 |     Ana Borges     |   Multicare   | 36.23157894736841  | 1.025108466661481  |
# | ALT_unidades_por_L |                Clínica geral                 |     Ana Borges     | Santa Clínica | 36.459583333333335 | 1.1639381395734165 |
# | ALT_unidades_por_L |                Clínica geral                 |     Ana Borges     |  Ultramedical | 35.97052631578947  | 1.5523762204519127 |
# | ALT_unidades_por_L |                Clínica geral                 |     Ana Borges     |      None     | 36.332653061224484 | 1.2297762356350836 |
# | ALT_unidades_por_L |                Clínica geral                 |    Aurora Moura    |      Blue     | 36.24263157894736  | 1.3037204970786174 |
# | ALT_unidades_por_L |                Clínica geral                 |    Aurora Moura    | Interclínicas |       36.11        | 1.0836902765018293 |
# | ALT_unidades_por_L |                Clínica geral                 |    Aurora Moura    |   Multicare   | 36.36277777777778  | 1.1410305226394106 |
# | ALT_unidades_por_L |                Clínica geral                 |    Aurora Moura    | Santa Clínica | 36.65769230769231  | 0.9242848933649004 |
# | ALT_unidades_por_L |                Clínica geral                 |    Aurora Moura    |  Ultramedical | 36.71636363636364  | 1.1121355378484448 |
# | ALT_unidades_por_L |                Clínica geral                 |    Aurora Moura    |      None     | 36.388133333333336 | 1.1285073774242254 |
# | ALT_unidades_por_L |                Clínica geral                 | Bernardina Andrade |      Blue     |       36.465       | 0.999571967217497  |
# | ALT_unidades_por_L |                Clínica geral                 | Bernardina Andrade | Interclínicas | 36.536428571428566 | 1.2771699913532202 |
# | ALT_unidades_por_L |                Clínica geral                 | Bernardina Andrade |   Multicare   | 36.66214285714286  | 1.4165786441087753 |
# | ALT_unidades_por_L |                Clínica geral                 | Bernardina Andrade | Santa Clínica | 36.393636363636375 | 0.9370407966281192 |
# | ALT_unidades_por_L |                Clínica geral                 | Bernardina Andrade |  Ultramedical | 36.66272727272728  | 1.1688720281458609 |
# | ALT_unidades_por_L |                Clínica geral                 | Bernardina Andrade |      None     | 36.54073529411765  | 1.1423480873908722 |
# | ALT_unidades_por_L |                Clínica geral                 |  Catarina Novais   |      Blue     |      36.4685       | 1.3564515433562978 |
# | ALT_unidades_por_L |                Clínica geral                 |  Catarina Novais   | Interclínicas | 36.31315789473683  | 0.9584886983138212 |
# | ALT_unidades_por_L |                Clínica geral                 |  Catarina Novais   |   Multicare   | 35.74454545454545  | 1.231774034767448  |
# +--------------------+----------------------------------------------+--------------------+---------------+--------------------+--------------------+
# Truncated to displaylimit of 100.

# %% [markdown]
# ## 6. Índices

# %% [markdown]
# Apresente as instruções SQL para criação de índices para melhorar os tempos de cada uma das consultas listadas abaixo sobre a base de dados ‘Saude’. Justifique a sua escolha de tabela(s), atributo(s) e tipo(s) de índice, explicando que operações seriam otimizadas e como. Considere que não existam índices nas tabelas, além daqueles implícitos ao declarar chaves primárias e estrangeiras, e para efeitos deste exercício, suponha que o tamanho das tabelas excede a memória disponível em várias ordens de magnitude.

# %% [markdown]
# ### 6.1
# SELECT nome
# FROM paciente
# JOIN consulta USING (ssn)
# JOIN observacao USING (id)
# WHERE parametro = ‘pressão diastólica’
# AND valor >= 9;

# %%
# %%sql
# CREATE INDEX index611 ON observacao USING btree (parametro, valor);
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# ### Justificação
#
# Visto que a query é da forma 'where a=constant1 and b >= constant2', usamos um index composto btree sobre observacao.
# Desta forma eliminamos o passo de filtrar as linhas de observacao sequencialmente.
# Não é necessário criar indices sobre ssn em consulta nem id em observacao pois esses já são primary keys das tabelas envolvidas no join.

# %% [markdown]
# ### 6.2
# SELECT especialidade, SUM(quantidade) AS qtd
# FROM medico
# JOIN consulta USING (nif)
# JOIN receita USING (codigo_sns)
# WHERE data BETWEEN ‘2023-01-01’ AND ‘2023-12-31’
# GROUP BY especialidade
# ORDER BY qtd;

# %%
# %%sql
# create index index621 on receita (codigo_sns);
# create index index622 on consulta (data);
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# ### Justificação
#
# Visto que codigo_sns não é primary key de consulta nem receita, um indice sobre ele pode melhorar a performance do join.
# Um indice sobre data em consulta permite fazer o passo de filtragem por data, evitando um seq scan.
# Não é possivel evitar o sort do group by com indices pois está a agroupar o join de tabelas distintas, e não é possivel evitar o sort do order by pois está a operar sobre um agregado de dados sobre os agrupamentos de joins de tabelas distintas.
